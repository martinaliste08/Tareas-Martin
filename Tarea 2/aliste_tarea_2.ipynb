# %% [markdown]
# Clasificador de temperatura:
# Crea un programa que imprima numeros desde -30 hasta 50
# Para cada número, ademas de imprimirlo, el programa debe mostrar un texto según estas reglas:
# si el numero es menor que 0, mostrar "muy frio", si el numero esta entre 0 y 24 mostrar "templado" si el numero es mayor o igual a 25, mostrar "caluroso".

# %%
# lista desde -30 al 50
lista_numeros = range(-30,50)
print(lista_numeros)

for x in range (-30,51):
   if (x < 0):
    print(x, "muy frio")
   elif(x >= 0 and x <=24):
    print(x, "templado")
   else:
    print(x, "caluroso")
# Out:
# range(-30, 50)
# -30 muy frio
# -29 muy frio
# -28 muy frio
# -27 muy frio
# -26 muy frio
# -25 muy frio
# -24 muy frio
# -23 muy frio
# -22 muy frio
# -21 muy frio
# -20 muy frio
# -19 muy frio
# -18 muy frio
# -17 muy frio
# -16 muy frio
# -15 muy frio
# -14 muy frio
# -13 muy frio
# -12 muy frio
# -11 muy frio
# -10 muy frio
# -9 muy frio
# -8 muy frio
# -7 muy frio
# -6 muy frio
# -5 muy frio
# -4 muy frio
# -3 muy frio
# -2 muy frio
# -1 muy frio
# 0 templado
# 1 templado
# 2 templado
# 3 templado
# 4 templado
# 5 templado
# 6 templado
# 7 templado
# 8 templado
# 9 templado
# 10 templado
# 11 templado
# 12 templado
# 13 templado
# 14 templado
# 15 templado
# 16 templado
# 17 templado
# 18 templado
# 19 templado
# 20 templado
# 21 templado
# 22 templado
# 23 templado
# 24 templado
# 25 caluroso
# 26 caluroso
# 27 caluroso
# 28 caluroso
# 29 caluroso
# 30 caluroso
# 31 caluroso
# 32 caluroso
# 33 caluroso
# 34 caluroso
# 35 caluroso
# 36 caluroso
# 37 caluroso
# 38 caluroso
# 39 caluroso
# 40 caluroso
# 41 caluroso
# 42 caluroso
# 43 caluroso
# 44 caluroso
# 45 caluroso
# 46 caluroso
# 47 caluroso
# 48 caluroso
# 49 caluroso
# 50 caluroso

# %% [markdown]
# Números especiales del robot:
# Crea un programa que imprima los números del 1 al 100 que sean divisibles por 5.
#
# Además, el programa debe cumplir estas condiciones:
#
# si el número es divisible por 5, imprimir el número junto con el texto "Bip" si el número también es divisible por 10, imprimir el número junto con el texto "Bip Bip" Ejemplo de salida

# %%
for x in range(1, 101):
    if(x % 10 == 0):
        print(x, "Bip Bip")
    elif(x % 5 == 0):
        print(x, "Bip")
# Out:
# 5 Bip
# 10 Bip Bip
# 15 Bip
# 20 Bip Bip
# 25 Bip
# 30 Bip Bip
# 35 Bip
# 40 Bip Bip
# 45 Bip
# 50 Bip Bip
# 55 Bip
# 60 Bip Bip
# 65 Bip
# 70 Bip Bip
# 75 Bip
# 80 Bip Bip
# 85 Bip
# 90 Bip Bip
# 95 Bip
# 100 Bip Bip

# %% [markdown]
# Problema 3. Detector de puntaje gamer
# Crea un programa que solicite al usuario dos números, los sume y luego muestre un mensaje según el resultado.
#
# Reglas
#
# si la suma es menor que 50, mostrar "Nivel principiante"
# si la suma es mayor o igual a 50 y menor que 80, mostrar "Nivel intermedio"
# si la suma es mayor o igual a 80, mostrar "Nivel pro"

# %%
numero1 = int(input("primer numero:"))
numero2 = int(input("segundo numero:"))

suma = numero1 + numero2

if (suma < 50):
   print ("nivel principiante")
elif (suma < 80):
   print ("nivel intermedio")
else:
   print ("nivel pro")
# Out:
# primer numero:20
# segundo numero:10
# nivel principiante

# %% [markdown]
# Problema 4. Calculador de perfil musical
# Crea un programa que evalúe el perfil del usuario según su edad y sus gustos.
#
# El usuario debe recibir los siguientes parámetros:
#
# edad
#
# le_gusta_musica
#
# le_gusta_bailar
#
# Y debe retornar uno de los siguientes mensajes:
#
# "Eres una estrella de la fiesta" si la persona tiene 18 o más años,
# le gusta la música y le gusta bailar
#
# "Te gusta la música, pero no tanto bailar" si le gusta la música pero no le gusta bailar
#
# "Tienes tu propio estilo" en cualquier otro caso

# %%
edad = int(input("edad:"))
le_gusta_musica = input("te gusta la musica (si/no)")
le_gusta_bailar = input ("te gusta bailar (si/no)")

if (edad > 18) and (le_gusta_musica == "si") and (le_gusta_bailar == "si"):
    print("eres una estrella de la fiesta")
elif le_gusta_musica == "si" and le_gusta_bailar == "no":
    print("Te gusta la música, pero no tanto bailar")
else:
    print("tienes tu propio estilo")
# Out:
# edad:21
# te gusta la musica (si/no)si
# te gusta bailar (si/no)no
# Te gusta la música, pero no tanto bailar
